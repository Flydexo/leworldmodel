# %%
from stable_worldmodel.wm.utils import save_pretrained

model_config = {
    '_target_': 'custom.models.MyWorldModel',
    'hidden_dim': 192,
    'action_dim': 10,
}

save_pretrained(
    model=model,
    run_name='tutorial_state_wm',
    config=model_config,
    filename='weights.pt',
)
