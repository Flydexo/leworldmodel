# %%
import torch, torch.nn as nn, torch.nn.functional as F
import datasets

# %%
from transformers import AutoModel
vit = AutoModel.from_pretrained("timm/vit_tiny_patch16_224.augreg_in21k", dtype="auto")
# Out:
# model.safetensors:   0%|          | 0.00/39.0M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/150 [00:00<?, ?it/s]
# [transformers] TimmWrapperModel LOAD REPORT from: timm/vit_tiny_patch16_224.augreg_in21k
# Key                    | Status     |  |
# -----------------------+------------+--+-
# timm_model.head.weight | UNEXPECTED |  |
# timm_model.head.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
